# %%
import sys, os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas_profiling

#sys.path.insert(0, os.path.abspath('..'))
from analysis.scripts import project_functions

# %%
df = project_functions.load_and_process(../data/raw/netflix_titles.csv)
df
# Out:
#   File "<ipython-input-43-7968b58eeb24>", line 1
#     df = project_functions.load_and_process(../data/raw/netflix_titles.csv)
#                                             ^
# SyntaxError: invalid syntax

# %%
df0 = pd.read_csv("netflix_titles.csv")
df2 = df0[["type", "release_year"]]
df2
# Out:
#          type  release_year
# 0       Movie          2019
# 1       Movie          2016
# 2     TV Show          2013
# 3     TV Show          2016
# 4       Movie          2017
# ...       ...           ...
# 6229  TV Show          2015
# 6230  TV Show          2016
# 6231    Movie          2016
# 6232  TV Show          2013
# 6233  TV Show          2003
#
# [6234 rows x 2 columns]

# %%
sns.violinplot(x="type", y="release_year", data=df2, palette="Pastel1")
# Out:
# <AxesSubplot:xlabel='type', ylabel='release_year'>

# %%
sns.boxplot(x="release_year", y="type", data=df2)
# Out:
# <AxesSubplot:xlabel='release_year', ylabel='type'>

# %%
sns.jointplot(x="type", y="release_year", kind="hex", data=df2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-f0793bcbfcc0> in <module>
# ----> 1 sns.jointplot(x="type", y="release_year", kind="hex", data=df2)
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\axisgrid.py in jointplot(x, y, data, kind, color, height, ratio, space, dropna, xlim, ylim, marginal_ticks, joint_kws, marginal_kws, hue, palette, hue_order, hue_norm, **kwargs)
#    2116     elif kind.startswith("hex"):
#    2117
# -> 2118         x_bins = min(_freedman_diaconis_bins(grid.x), 50)
#    2119         y_bins = min(_freedman_diaconis_bins(grid.y), 50)
# ...
